# %% [markdown]
# # To create an ensemble model

# %% [markdown]
# ## understnding loading and saving structure of model

# %%
path = "/gpfs01/euler/User/ssuhai/GitRepos/open-retina/openretina_assets/runs/hoefling_2024_core_readout_low_res_filtered/train_all_no_loading2/tensorboard"

# %%
# Load TensorBoard extension
# %load_ext tensorboard

# Start TensorBoard pointing to your log directory
# %tensorboard --logdir /gpfs01/euler/User/ssuhai/GitRepos/open-retina/openretina_assets/runs/hoefling_2024_core_readout_low_res_filtered/train_all_no_loading2/tensorboard
# Out:
# Launching TensorBoard...

# %%
import torch

# %%
from openretina.models.core_readout import load_core_readout_model

# %%
model = load_core_readout_model("hoefling_2024_base_low_res",device="cuda",is_gru_model=False)

# %%
enselmble_dir = "/gpfs01/euler/User/ssuhai/GitRepos/simulation_closed_loop/models/ensemble"

seed = 
state_dict_path = f"{enselmble_dir}/"

torch.save
