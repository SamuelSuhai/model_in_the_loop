# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## inspecting mouse cam stimulus

# %%
import pickle
_path = '/gpfs01/euler/User/ssuhai/openretina_cache/euler_lab/hoefling_2024/stimuli/rgc_natstim_72x64_joint_normalized_2024-10-11.pkl'
with open(_path, 'rb') as f:
    data = pickle.load(f)

# %%
108 * 150
# Out:
# 16200

# %%
data['train'].shape
# Out:
# (2, 16200, 72, 64)

# %%
import h5py
import os 
import numpy as np  
import matplotlib.pyplot as plt 
path = '/gpfs01/euler/User/ssuhai/openretia_cache/data/euler_lab/hoefling_2024/responses/rgc_natstim_2024-08-14.h5'

"print all dataset sin hfd5 file"
with h5py.File(path, 'r') as f:
    def printname(name):
        print(name)
    def printshape(name, obj):
        print(name, obj.shape)
    f.visit(printname)
    f.visititems(printshape)
    # wDataCh0 = f['wDataCh0'][:]
    # wParamsStr = f['wParamsStr'][:]
# Out:
# session_1_ventral1_20200226
# session_1_ventral1_20200226/chirp_preprocessed_traces
# session_1_ventral1_20200226/chirp_qi
# session_1_ventral1_20200226/chirp_raw_traces
# session_1_ventral1_20200226/chirp_smoothed_traces
# session_1_ventral1_20200226/chirp_spike_times
# session_1_ventral1_20200226/chirp_spikes
# session_1_ventral1_20200226/chirp_traces_times
# session_1_ventral1_20200226/chirp_trigger_times
# session_1_ventral1_20200226/d_qi
# session_1_ventral1_20200226/ds_index
# session_1_ventral1_20200226/group_assignment
# session_1_ventral1_20200226/group_confidences
# session_1_ventral1_20200226/mb_preprocessed_traces
# session_1_ventral1_20200226/mb_raw_traces
# session_1_ventral1_20200226/mb_smoothed_traces
# session_1_ventral1_20200226/mb_spike_times
# session_1_ventral1_20200226/mb_spikes
# session_1_ventral1_20200226/mb_traces_times
# session_1_ventral1_20200226/mb_trigger_times
# session_1_ventral1_20200226/natural_preprocessed_traces
# session_1_ventral1_20200226/natural_raw_traces
# session_1_ventral1_20200226/natural_smoothed_traces
# session_1_ventral1_20200226/natural_spike_times
# session_1_ventral1_20200226/natural_spikes
# session_1_ventral1_20200226/natural_traces_times
# session_1_ventral1_20200226/natural_trigger_times
# session_1_ventral1_20200226/os_index
# session_1_ventral1_20200226/pref_dir
# session_1_ventral1_20200226/roi_ids
# session_1_ventral1_20200226/roi_retinal_coords
# session_1_ventral1_20200226/roi_size_um2
# session_1_ventral1_20200528
# session_1_ventral1_20200528/chirp_preprocessed_traces
# session_1_ventral1_20200528/chirp_qi
# session_1_ventral1_20200528/chirp_raw_traces
# session_1_ventral1_20200528/chirp_smoothed_traces
# session_1_ventral1_20200528/chirp_spike_times
# session_1_ventral1_20200528/chirp_spikes
# session_1_ventral1_20200528/chirp_traces_times
# session_1_ventral1_20200528/chirp_trigger_times
# session_1_ventral1_20200528/d_qi
# session_1_ventral1_20200528/ds_index
# session_1_ventral1_20200528/group_assignment
# session_1_ventral1_20200528/group_confidences
# session_1_ventral1_20200528/mb_preprocessed_traces
# session_1_ventral1_20200528/mb_raw_traces
# session_1_ventral1_20200528/mb_smoothed_traces
# session_1_ventral1_20200528/mb_spike_times
# session_1_ventral1_20200528/mb_spikes
# session_1_ventral1_20200528/mb_traces_times
# session_1_ventral1_20200528/mb_trigger_times
# session_1_ventral1_20200528/natural_preprocessed_traces
# session_1_ventral1_20200528/natural_raw_traces
# session_1_ventral1_20200528/natural_smoothed_traces
# session_1_ventral1_20200528/natural_spike_times
# session_1_ventral1_20200528/natural_spikes
# session_1_ventral1_20200528/natural_traces_times
# session_1_ventral1_20200528/natural_trigger_times
# session_1_ventral1_20200528/os_index
# session_1_ventral1_20200528/pref_dir
# session_1_ventral1_20200528/roi_ids
# session_1_ventral1_20200528/roi_retinal_coords
# session_1_ventral1_20200528/roi_size_um2
# session_1_ventral1_20200707
# session_1_ventral1_20200707/chirp_preprocessed_traces
# session_1_ventral1_20200707/chirp_qi
# session_1_ventral1_20200707/chirp_raw_traces
# session_1_ventral1_20200707/chirp_smoothed_traces
# session_1_ventral1_20200707/chirp_spike_times
# session_1_ventral1_20200707/chirp_spikes
# session_1_ventral1_20200707/chirp_traces_times
# session_1_ventral1_20200707/chirp_trigger_times
# session_1_ventral1_20200707/d_qi
# session_1_ventral1_20200707/ds_index
# session_1_ventral1_20200707/group_assignment
# session_1_ventral1_20200707/group_confidences
# session_1_ventral1_20200707/mb_preprocessed_traces
# session_1_ventral1_20200707/mb_raw_traces
# session_1_ventral1_20200707/mb_smoothed_traces
# session_1_ventral1_20200707/mb_spike_times
# session_1_ventral1_20200707/mb_spikes
# session_1_ventral1_20200707/mb_traces_times
# session_1_ventral1_20200707/mb_trigger_times
# session_1_ventral1_20200707/natural_preprocessed_traces
# session_1_ventral1_20200707/natural_raw_traces
# session_1_ventral1_20200707/natural_smoothed_traces
# session_1_ventral1_20200707/natural_spike_times
# session_1_ventral1_20200707/natural_spikes
# session_1_ventral1_20200707/natural_traces_times
# session_1_ventral1_20200707/natural_trigger_times
# session_1_ventral1_20200707/os_index
# session_1_ventral1_20200707/pref_dir
# session_1_ventral1_20200707/roi_ids
# session_1_ventral1_20200707/roi_retinal_coords
# session_1_ventral1_20200707/roi_size_um2
# session_1_ventral1_20201021
# session_1_ventral1_20201021/chirp_preprocessed_traces
# session_1_ventral1_20201021/chirp_qi
# session_1_ventral1_20201021/chirp_raw_traces
# session_1_ventral1_20201021/chirp_smoothed_traces
# session_1_ventral1_20201021/chirp_spike_times
# session_1_ventral1_20201021/chirp_spikes
# session_1_ventral1_20201021/chirp_traces_times
# session_1_ventral1_20201021/chirp_trigger_times
# session_1_ventral1_20201021/d_qi
# session_1_ventral1_20201021/ds_index
# session_1_ventral1_20201021/group_assignment
# session_1_ventral1_20201021/group_confidences
# session_1_ventral1_20201021/mb_preprocessed_traces
# session_1_ventral1_20201021/mb_raw_traces
# session_1_ventral1_20201021/mb_smoothed_traces
# session_1_ventral1_20201021/mb_spike_times
# session_1_ventral1_20201021/mb_spikes
# session_1_ventral1_20201021/mb_traces_times
# session_1_ventral1_20201021/mb_trigger_times
# session_1_ventral1_20201021/natural_preprocessed_traces
# session_1_ventral1_20201021/natural_raw_traces
# session_1_ventral1_20201021/natural_smoothed_traces
# session_1_ventral1_20201021/natural_spike_times
# session_1_ventral1_20201021/natural_spikes
# session_1_ventral1_20201021/natural_traces_times
# session_1_ventral1_20201021/natural_trigger_times
# session_1_ventral1_20201021/os_index
# session_1_ventral1_20201021/pref_dir
# session_1_ventral1_20201021/roi_ids
# session_1_ventral1_20201021/roi_retinal_coords
# session_1_ventral1_20201021/roi_size_um2
# session_1_ventral1_20201030
# session_1_ventral1_20201030/chirp_preprocessed_traces
# session_1_ventral1_20201030/chirp_qi
# session_1_ventral1_20201030/chirp_raw_traces
# session_1_ventral1_20201030/chirp_smoothed_traces
# session_1_ventral1_20201030/chirp_spike_times
# session_1_ventral1_20201030/chirp_spikes
# session_1_ventral1_20201030/chirp_traces_times
# session_1_ventral1_20201030/chirp_trigger_times
# session_1_ventral1_20201030/d_qi
# session_1_ventral1_20201030/ds_index
# session_1_ventral1_20201030/group_assignment
# session_1_ventral1_20201030/group_confidences
# session_1_ventral1_20201030/mb_preprocessed_traces
# session_1_ventral1_20201030/mb_raw_traces
# session_1_ventral1_20201030/mb_smoothed_traces
# session_1_ventral1_20201030/mb_spike_times
# session_1_ventral1_20201030/mb_spikes
# session_1_ventral1_20201030/mb_traces_times
# session_1_ventral1_20201030/mb_trigger_times
# session_1_ventral1_20201030/natural_preprocessed_traces
# session_1_ventral1_20201030/natural_raw_traces
# session_1_ventral1_20201030/natural_smoothed_traces
# session_1_ventral1_20201030/natural_spike_times
# session_1_ventral1_20201030/natural_spikes
# session_1_ventral1_20201030/natural_traces_times
# session_1_ventral1_20201030/natural_trigger_times
# session_1_ventral1_20201030/os_index
# session_1_ventral1_20201030/pref_dir
# session_1_ventral1_20201030/roi_ids
# session_1_ventral1_20201030/roi_retinal_coords
# session_1_ventral1_20201030/roi_size_um2
# session_1_ventral1_20210929
# session_1_ventral1_20210929/chirp_preprocessed_traces
# session_1_ventral1_20210929/chirp_qi
# session_1_ventral1_20210929/chirp_raw_traces
# session_1_ventral1_20210929/chirp_smoothed_traces
# session_1_ventral1_20210929/chirp_spike_times
# session_1_ventral1_20210929/chirp_spikes
# session_1_ventral1_20210929/chirp_traces_times
# session_1_ventral1_20210929/chirp_trigger_times
# session_1_ventral1_20210929/d_qi
# session_1_ventral1_20210929/ds_index
# session_1_ventral1_20210929/group_assignment
# session_1_ventral1_20210929/group_confidences
# session_1_ventral1_20210929/mb_preprocessed_traces
# session_1_ventral1_20210929/mb_raw_traces
# session_1_ventral1_20210929/mb_smoothed_traces
# session_1_ventral1_20210929/mb_spike_times
# session_1_ventral1_20210929/mb_spikes
# session_1_ventral1_20210929/mb_traces_times
# session_1_ventral1_20210929/mb_trigger_times
# session_1_ventral1_20210929/natural_preprocessed_traces
# session_1_ventral1_20210929/natural_raw_traces
# session_1_ventral1_20210929/natural_smoothed_traces
# session_1_ventral1_20210929/natural_spike_times
# session_1_ventral1_20210929/natural_spikes
# session_1_ventral1_20210929/natural_traces_times
# session_1_ventral1_20210929/natural_trigger_times
# session_1_ventral1_20210929/os_index
# session_1_ventral1_20210929/pref_dir
# session_1_ventral1_20210929/roi_ids
# session_1_ventral1_20210929/roi_retinal_coords
# session_1_ventral1_20210929/roi_size_um2
# session_1_ventral2_20201022/mb_preprocessed_traces
# session_1_ventral2_20201022/mb_raw_traces
# session_1_ventral2_20201022/mb_smoothed_traces
# session_1_ventral2_20201022/mb_spike_times
# session_1_ventral2_20201022/mb_spikes
# session_1_ventral2_20201022/mb_traces_times
# session_1_ventral2_20201022/mb_trigger_times
# session_1_ventral2_20201022/natural_preprocessed_traces
# session_1_ventral2_20201022/natural_raw_traces
# session_1_ventral2_20201022/natural_smoothed_traces
# session_1_ventral2_20201022/natural_spike_times
# session_1_ventral2_20201022/natural_spikes
# session_1_ventral2_20201022/natural_traces_times
# session_1_ventral2_20201022/natural_trigger_times
# session_1_ventral2_20201022/os_index
# session_1_ventral2_20201022/pref_dir
# session_1_ventral2_20201022/roi_ids
# session_1_ventral2_20201022/roi_retinal_coords
# session_1_ventral2_20201022/roi_size_um2
# session_1_ventral2_20201030
# session_1_ventral2_20201030/chirp_preprocessed_traces
# session_1_ventral2_20201030/chirp_qi
# session_1_ventral2_20201030/chirp_raw_traces
# session_1_ventral2_20201030/chirp_smoothed_traces
# session_1_ventral2_20201030/chirp_spike_times
# session_1_ventral2_20201030/chirp_spikes
# session_1_ventral2_20201030/chirp_traces_times
# session_1_ventral2_20201030/chirp_trigger_times
# session_1_ventral2_20201030/d_qi
# session_1_ventral2_20201030/ds_index
# session_1_ventral2_20201030/group_assignment
# session_1_ventral2_20201030/group_confidences
# session_1_ventral2_20201030/mb_preprocessed_traces
# session_1_ventral2_20201030/mb_raw_traces
# session_1_ventral2_20201030/mb_smoothed_traces
# session_1_ventral2_20201030/mb_spike_times
# session_1_ventral2_20201030/mb_spikes
# session_1_ventral2_20201030/mb_traces_times
# session_1_ventral2_20201030/mb_trigger_times
# session_1_ventral2_20201030/natural_preprocessed_traces
# session_1_ventral2_20201030/natural_raw_traces
# session_1_ventral2_20201030/natural_smoothed_traces
# session_1_ventral2_20201030/natural_spike_times
# session_1_ventral2_20201030/natural_spikes
# session_1_ventral2_20201030/natural_traces_times
# session_1_ventral2_20201030/natural_trigger_times
# session_1_ventral2_20201030/os_index
# session_1_ventral2_20201030/pref_dir
# session_1_ventral2_20201030/roi_ids
# session_1_ventral2_20201030/roi_retinal_coords
# session_1_ventral2_20201030/roi_size_um2
# session_1_ventral2_20201117
# session_1_ventral2_20201117/chirp_preprocessed_traces
# session_1_ventral2_20201117/chirp_qi
# session_1_ventral2_20201117/chirp_raw_traces
# session_1_ventral2_20201117/chirp_smoothed_traces
# session_1_ventral2_20201117/chirp_spike_times
# session_1_ventral2_20201117/chirp_spikes
# session_1_ventral2_20201117/chirp_traces_times
# session_1_ventral2_20201117/chirp_trigger_times
# session_1_ventral2_20201117/d_qi
# session_1_ventral2_20201117/ds_index
# session_1_ventral2_20201117/group_assignment
# session_1_ventral2_20201117/group_confidences
# session_1_ventral2_20201117/mb_preprocessed_traces
# session_1_ventral2_20201117/mb_raw_traces
# session_1_ventral2_20201117/mb_smoothed_traces
# session_1_ventral2_20201117/mb_spike_times
# session_1_ventral2_20201117/mb_spikes
# session_1_ventral2_20201117/mb_traces_times
# session_1_ventral2_20201117/mb_trigger_times
# session_1_ventral2_20201117/natural_preprocessed_traces
# session_1_ventral2_20201117/natural_raw_traces
# session_1_ventral2_20201117/natural_smoothed_traces
# session_1_ventral2_20201117/natural_spike_times
# session_1_ventral2_20201117/natural_spikes
# session_1_ventral2_20201117/natural_traces_times
# session_1_ventral2_20201117/natural_trigger_times
# session_1_ventral2_20201117/os_index
# session_1_ventral2_20201117/pref_dir
# session_1_ventral2_20201117/roi_ids
# session_1_ventral2_20201117/roi_retinal_coords
# session_1_ventral2_20201117/roi_size_um2
# session_1_ventral2_20210910
# session_1_ventral2_20210910/chirp_preprocessed_traces
# session_1_ventral2_20210910/chirp_qi
# session_1_ventral2_20210910/chirp_raw_traces
# session_1_ventral2_20210910/chirp_smoothed_traces
# session_1_ventral2_20210910/chirp_spike_times
# session_1_ventral2_20210910/chirp_spikes
# session_1_ventral2_20210910/chirp_traces_times
# session_1_ventral2_20210910/chirp_trigger_times
# session_1_ventral2_20210910/d_qi
# session_1_ventral2_20210910/ds_index
# session_1_ventral2_20210910/group_assignment
# session_1_ventral2_20210910/group_confidences
# session_1_ventral2_20210910/mb_preprocessed_traces
# session_1_ventral2_20210910/mb_raw_traces
# session_1_ventral2_20210910/mb_smoothed_traces
# session_1_ventral2_20210910/mb_spike_times
# session_1_ventral2_20210910/mb_spikes
# session_1_ventral2_20210910/mb_traces_times
# session_1_ventral2_20210910/mb_trigger_times
# session_1_ventral2_20210910/natural_preprocessed_traces
# session_1_ventral2_20210910/natural_raw_traces
# session_1_ventral2_20210910/natural_smoothed_traces
# session_1_ventral2_20210910/natural_spike_times
# session_1_ventral2_20210910/natural_spikes
# session_1_ventral2_20210910/natural_traces_times
# session_1_ventral2_20210910/natural_trigger_times
# session_1_ventral2_20210910/os_index
# session_1_ventral2_20210910/pref_dir
# session_1_ventral2_20210910/roi_ids
# session_1_ventral2_20210910/roi_retinal_coords
# session_1_ventral2_20210910/roi_size_um2
# session_1_ventral2_20210921
# session_1_ventral2_20210921/chirp_preprocessed_traces
# session_1_ventral2_20210921/chirp_qi
# session_1_ventral2_20210921/chirp_raw_traces
# session_1_ventral2_20210921/chirp_smoothed_traces
# session_1_ventral2_20210921/chirp_spike_times
# session_1_ventral2_20210921/chirp_spikes
# session_1_ventral2_20210921/chirp_traces_times
# session_1_ventral2_20210921/chirp_trigger_times
# session_1_ventral2_20210921/d_qi
# session_1_ventral2_20210921/ds_index
# session_1_ventral2_20210921/group_assignment
# session_1_ventral2_20210921/group_confidences
# session_1_ventral2_20210921/mb_preprocessed_traces
# session_1_ventral2_20210921/mb_raw_traces
# session_1_ventral2_20210921/mb_smoothed_traces
# session_1_ventral2_20210921/mb_spike_times
# session_1_ventral2_20210921/mb_spikes
# session_1_ventral2_20210921/mb_traces_times
# session_1_ventral2_20210921/mb_trigger_times
# session_1_ventral2_20210921/natural_preprocessed_traces
# session_1_ventral2_20210921/natural_raw_traces
# session_1_ventral2_20210921/natural_smoothed_traces
# session_1_ventral2_20210921/natural_spike_times
# session_1_ventral2_20210921/natural_spikes
# session_2_ventral1_20201021/natural_preprocessed_traces
# session_2_ventral1_20201021/natural_raw_traces
# session_2_ventral1_20201021/natural_smoothed_traces
# session_2_ventral1_20201021/natural_spike_times
# session_2_ventral1_20201021/natural_spikes
# session_2_ventral1_20201021/natural_traces_times
# session_2_ventral1_20201021/natural_trigger_times
# session_2_ventral1_20201021/os_index
# session_2_ventral1_20201021/pref_dir
# session_2_ventral1_20201021/roi_ids
# session_2_ventral1_20201021/roi_retinal_coords
# session_2_ventral1_20201021/roi_size_um2
# session_2_ventral1_20201030
# session_2_ventral1_20201030/chirp_preprocessed_traces
# session_2_ventral1_20201030/chirp_qi
# session_2_ventral1_20201030/chirp_raw_traces
# session_2_ventral1_20201030/chirp_smoothed_traces
# session_2_ventral1_20201030/chirp_spike_times
# session_2_ventral1_20201030/chirp_spikes
# session_2_ventral1_20201030/chirp_traces_times
# session_2_ventral1_20201030/chirp_trigger_times
# session_2_ventral1_20201030/d_qi
# session_2_ventral1_20201030/ds_index
# session_2_ventral1_20201030/group_assignment
# session_2_ventral1_20201030/group_confidences
# session_2_ventral1_20201030/mb_preprocessed_traces
# session_2_ventral1_20201030/mb_raw_traces
# session_2_ventral1_20201030/mb_smoothed_traces
# session_2_ventral1_20201030/mb_spike_times
# session_2_ventral1_20201030/mb_spikes
# session_2_ventral1_20201030/mb_traces_times
# session_2_ventral1_20201030/mb_trigger_times
# session_2_ventral1_20201030/natural_preprocessed_traces
# session_2_ventral1_20201030/natural_raw_traces
# session_2_ventral1_20201030/natural_smoothed_traces
# session_2_ventral1_20201030/natural_spike_times
# session_2_ventral1_20201030/natural_spikes
# session_2_ventral1_20201030/natural_traces_times
# session_2_ventral1_20201030/natural_trigger_times
# session_2_ventral1_20201030/os_index
# session_2_ventral1_20201030/pref_dir
# session_2_ventral1_20201030/roi_ids
# session_2_ventral1_20201030/roi_retinal_coords
# session_2_ventral1_20201030/roi_size_um2
# session_2_ventral1_20210929
# session_2_ventral1_20210929/chirp_preprocessed_traces
# session_2_ventral1_20210929/chirp_qi
# session_2_ventral1_20210929/chirp_raw_traces
# session_2_ventral1_20210929/chirp_smoothed_traces
# session_2_ventral1_20210929/chirp_spike_times
# session_2_ventral1_20210929/chirp_spikes
# session_2_ventral1_20210929/chirp_traces_times
# session_2_ventral1_20210929/chirp_trigger_times
# session_2_ventral1_20210929/d_qi
# session_2_ventral1_20210929/ds_index
# session_2_ventral1_20210929/group_assignment
# session_2_ventral1_20210929/group_confidences
# session_2_ventral1_20210929/mb_preprocessed_traces
# session_2_ventral1_20210929/mb_raw_traces
# session_2_ventral1_20210929/mb_smoothed_traces
# session_2_ventral1_20210929/mb_spike_times
# session_2_ventral1_20210929/mb_spikes
# session_2_ventral1_20210929/mb_traces_times
# session_2_ventral1_20210929/mb_trigger_times
# session_2_ventral1_20210929/natural_preprocessed_traces
# session_2_ventral1_20210929/natural_raw_traces
# session_2_ventral1_20210929/natural_smoothed_traces
# session_2_ventral1_20210929/natural_spike_times
# session_2_ventral1_20210929/natural_spikes
# session_2_ventral1_20210929/natural_traces_times
# session_2_ventral2_20201030/chirp_traces_times
# session_2_ventral2_20201030/chirp_trigger_times
# session_2_ventral2_20201030/d_qi
# session_2_ventral2_20201030/ds_index
# session_2_ventral2_20201030/group_assignment
# session_2_ventral2_20201030/group_confidences
# session_2_ventral2_20201030/mb_preprocessed_traces
# session_2_ventral2_20201030/mb_raw_traces
# session_2_ventral2_20201030/mb_smoothed_traces
# session_2_ventral2_20201030/mb_spike_times
# session_2_ventral2_20201030/mb_spikes
# session_2_ventral2_20201030/mb_traces_times
# session_2_ventral2_20201030/mb_trigger_times
# session_2_ventral2_20201030/natural_preprocessed_traces
# session_2_ventral2_20201030/natural_raw_traces
# session_2_ventral2_20201030/natural_smoothed_traces
# session_2_ventral2_20201030/natural_spike_times
# session_2_ventral2_20201030/natural_spikes
# session_2_ventral2_20201030/natural_traces_times
# session_2_ventral2_20201030/natural_trigger_times
# session_2_ventral2_20201030/os_index
# session_2_ventral2_20201030/pref_dir
# session_2_ventral2_20201030/roi_ids
# session_2_ventral2_20201030/roi_retinal_coords
# session_2_ventral2_20201030/roi_size_um2
# session_2_ventral2_20201117
# session_2_ventral2_20201117/chirp_preprocessed_traces
# session_2_ventral2_20201117/chirp_qi
# session_2_ventral2_20201117/chirp_raw_traces
# session_2_ventral2_20201117/chirp_smoothed_traces
# session_2_ventral2_20201117/chirp_spike_times
# session_2_ventral2_20201117/chirp_spikes
# session_2_ventral2_20201117/chirp_traces_times
# session_2_ventral2_20201117/chirp_trigger_times
# session_2_ventral2_20201117/d_qi
# session_2_ventral2_20201117/ds_index
# session_2_ventral2_20201117/group_assignment
# session_2_ventral2_20201117/group_confidences
# session_2_ventral2_20201117/mb_preprocessed_traces
# session_2_ventral2_20201117/mb_raw_traces
# session_2_ventral2_20201117/mb_smoothed_traces
# session_2_ventral2_20201117/mb_spike_times
# session_2_ventral2_20201117/mb_spikes
# session_2_ventral2_20201117/mb_traces_times
# session_2_ventral2_20201117/mb_trigger_times
# session_2_ventral2_20201117/natural_preprocessed_traces
# session_2_ventral2_20201117/natural_raw_traces
# session_2_ventral2_20201117/natural_smoothed_traces
# session_2_ventral2_20201117/natural_spike_times
# session_2_ventral2_20201117/natural_spikes
# session_2_ventral2_20201117/natural_traces_times
# session_2_ventral2_20201117/natural_trigger_times
# session_2_ventral2_20201117/os_index
# session_2_ventral2_20201117/pref_dir
# session_2_ventral2_20201117/roi_ids
# session_2_ventral2_20201117/roi_retinal_coords
# session_2_ventral2_20201117/roi_size_um2
# session_2_ventral2_20210910
# session_2_ventral2_20210910/chirp_preprocessed_traces
# session_2_ventral2_20210910/chirp_qi
# session_2_ventral2_20210910/chirp_raw_traces
# session_2_ventral2_20210910/chirp_smoothed_traces
# session_2_ventral2_20210910/chirp_spike_times
# session_2_ventral2_20210910/chirp_spikes
# session_2_ventral2_20210910/chirp_traces_times
# session_2_ventral2_20210910/chirp_trigger_times
# session_2_ventral2_20210910/d_qi
# session_2_ventral2_20210910/ds_index
# session_2_ventral2_20210910/group_assignment
# session_2_ventral2_20210910/group_confidences
# session_2_ventral2_20210910/mb_preprocessed_traces
# session_2_ventral2_20210910/mb_raw_traces
# session_2_ventral2_20210910/mb_smoothed_traces
# session_2_ventral2_20210910/mb_spike_times
# session_2_ventral2_20210910/mb_spikes
# session_2_ventral2_20210910/mb_traces_times
# session_2_ventral2_20210910/mb_trigger_times
# session_2_ventral2_20210910/natural_preprocessed_traces
# session_2_ventral2_20210910/natural_raw_traces
# session_2_ventral2_20210910/natural_smoothed_traces
# session_2_ventral2_20210910/natural_spike_times
# session_2_ventral2_20210910/natural_spikes
# session_2_ventral2_20210910/natural_traces_times
# session_2_ventral2_20210910/natural_trigger_times
# session_2_ventral2_20210910/os_index
# session_2_ventral2_20210910/pref_dir
# session_2_ventral2_20210910/roi_ids
# session_2_ventral2_20210910/roi_retinal_coords
# session_2_ventral2_20210910/roi_size_um2
# session_2_ventral2_20210921
# session_2_ventral2_20210921/chirp_preprocessed_traces
# session_2_ventral2_20210921/chirp_qi
# session_2_ventral2_20210921/chirp_raw_traces
# session_2_ventral2_20210921/chirp_smoothed_traces
# session_2_ventral2_20210921/chirp_spike_times
# session_2_ventral2_20210921/chirp_spikes
# session_2_ventral2_20210921/chirp_traces_times
# session_2_ventral2_20210921/chirp_trigger_times
# session_2_ventral2_20210921/d_qi
# session_2_ventral2_20210921/ds_index
# session_2_ventral2_20210921/group_assignment
# session_2_ventral2_20210921/group_confidences
# session_2_ventral2_20210921/mb_preprocessed_traces
# session_2_ventral2_20210921/mb_raw_traces
# session_2_ventral2_20210921/mb_smoothed_traces
# session_2_ventral2_20210921/mb_spike_times
# session_2_ventral2_20210921/mb_spikes
# session_2_ventral2_20210921/mb_traces_times
# session_2_ventral2_20210921/mb_trigger_times
# session_2_ventral2_20210921/natural_preprocessed_traces
# session_2_ventral2_20210921/natural_raw_traces
# session_2_ventral2_20210921/natural_smoothed_traces
# session_2_ventral2_20210921/natural_spike_times
# session_2_ventral2_20210921/natural_spikes
# session_2_ventral2_20210921/natural_traces_times
# session_2_ventral2_20210921/natural_trigger_times
# session_2_ventral2_20210921/os_index
# session_2_ventral2_20210921/pref_dir
# session_2_ventral2_20210921/roi_ids
# session_2_ventral2_20210921/roi_retinal_coords
# session_2_ventral2_20210921/roi_size_um2
# session_2_ventral2_20210929
# ...
# session_4_ventral2_20201022/mb_traces_times
# session_4_ventral2_20201022/mb_trigger_times
# session_4_ventral2_20201022/natural_preprocessed_traces
# session_4_ventral2_20201022/natural_raw_traces
# session_4_ventral2_20201022/natural_smoothed_traces
# session_4_ventral2_20201022/natural_spike_times
# session_4_ventral2_20201022/natural_spikes
# session_4_ventral2_20201022/natural_traces_times
# session_4_ventral2_20201022/natural_trigger_times
# session_4_ventral2_20201022/os_index
# session_4_ventral2_20201022/pref_dir
# session_4_ventral2_20201022/roi_ids
# session_4_ventral2_20201022/roi_retinal_coords
# session_4_ventral2_20201022/roi_size_um2
# session_4_ventral2_20210910
# session_4_ventral2_20210910/chirp_preprocessed_traces
# session_4_ventral2_20210910/chirp_qi
# session_4_ventral2_20210910/chirp_raw_traces
# session_4_ventral2_20210910/chirp_smoothed_traces
# session_4_ventral2_20210910/chirp_spike_times
# session_4_ventral2_20210910/chirp_spikes
# session_4_ventral2_20210910/chirp_traces_times
# session_4_ventral2_20210910/chirp_trigger_times
# session_4_ventral2_20210910/d_qi
# session_4_ventral2_20210910/ds_index
# session_4_ventral2_20210910/group_assignment
# session_4_ventral2_20210910/group_confidences
# session_4_ventral2_20210910/mb_preprocessed_traces
# session_4_ventral2_20210910/mb_raw_traces
# session_4_ventral2_20210910/mb_smoothed_traces
# session_4_ventral2_20210910/mb_spike_times
# session_4_ventral2_20210910/mb_spikes
# session_4_ventral2_20210910/mb_traces_times
# session_4_ventral2_20210910/mb_trigger_times
# session_4_ventral2_20210910/natural_preprocessed_traces
# session_4_ventral2_20210910/natural_raw_traces
# session_4_ventral2_20210910/natural_smoothed_traces
# session_4_ventral2_20210910/natural_spike_times
# session_4_ventral2_20210910/natural_spikes
# session_4_ventral2_20210910/natural_traces_times
# session_4_ventral2_20210910/natural_trigger_times
# session_4_ventral2_20210910/os_index
# session_4_ventral2_20210910/pref_dir
# session_4_ventral2_20210910/roi_ids
# session_4_ventral2_20210910/roi_retinal_coords
# session_4_ventral2_20210910/roi_size_um2
# session_4_ventral2_20210921
# session_4_ventral2_20210921/chirp_preprocessed_traces
# session_4_ventral2_20210921/chirp_qi
# session_4_ventral2_20210921/chirp_raw_traces
# session_4_ventral2_20210921/chirp_smoothed_traces
# session_4_ventral2_20210921/chirp_spike_times
# session_4_ventral2_20210921/chirp_spikes
# session_4_ventral2_20210921/chirp_traces_times
# session_4_ventral2_20210921/chirp_trigger_times
# session_4_ventral2_20210921/d_qi
# session_4_ventral2_20210921/ds_index
# session_4_ventral2_20210921/group_assignment
# session_4_ventral2_20210921/group_confidences
# session_4_ventral2_20210921/mb_preprocessed_traces
# session_4_ventral2_20210921/mb_raw_traces
# session_4_ventral2_20210921/mb_smoothed_traces
# session_4_ventral2_20210921/mb_spike_times
# session_4_ventral2_20210921/mb_spikes
# session_4_ventral2_20210921/mb_traces_times
# session_4_ventral2_20210921/mb_trigger_times
# session_4_ventral2_20210921/natural_preprocessed_traces
# session_4_ventral2_20210921/natural_raw_traces
# session_4_ventral2_20210921/natural_smoothed_traces
# session_4_ventral2_20210921/natural_spike_times
# session_4_ventral2_20210921/natural_spikes
# session_4_ventral2_20210921/natural_traces_times
# session_4_ventral2_20210921/natural_trigger_times
# session_4_ventral2_20210921/os_index
# session_4_ventral2_20210921/pref_dir
# session_4_ventral2_20210921/roi_ids
# session_4_ventral2_20210921/roi_retinal_coords
# session_4_ventral2_20210921/roi_size_um2
# session_4_ventral2_20210929
# session_4_ventral2_20210929/chirp_preprocessed_traces
# session_4_ventral2_20210929/chirp_qi
# session_4_ventral2_20210929/chirp_raw_traces
# session_4_ventral2_20210929/chirp_smoothed_traces
# session_4_ventral2_20210929/chirp_spike_times
# session_4_ventral2_20210929/chirp_spikes
# session_4_ventral2_20210929/chirp_traces_times
# session_4_ventral2_20210929/chirp_trigger_times
# session_4_ventral2_20210929/d_qi
# session_4_ventral2_20210929/ds_index
# session_4_ventral2_20210929/group_assignment
# session_4_ventral2_20210929/group_confidences
# session_4_ventral2_20210929/mb_preprocessed_traces
# session_4_ventral2_20210929/mb_raw_traces
# session_4_ventral2_20210929/mb_smoothed_traces
# session_4_ventral2_20210929/mb_spike_times
# session_4_ventral2_20210929/mb_spikes
# session_4_ventral2_20210929/mb_traces_times
# session_4_ventral2_20210929/mb_trigger_times
# session_4_ventral2_20210929/natural_preprocessed_traces
# session_4_ventral2_20210929/natural_raw_traces
# session_4_ventral2_20210929/natural_smoothed_traces
# session_4_ventral2_20210929/natural_spike_times
# session_4_ventral2_20210929/natural_spikes
# session_4_ventral2_20210929/natural_traces_times
# session_4_ventral2_20210929/natural_trigger_times
# session_4_ventral2_20210929/os_index
# session_4_ventral2_20210929/pref_dir
# session_4_ventral2_20210929/roi_ids
# session_4_ventral2_20210929/roi_retinal_coords
# session_4_ventral2_20210929/roi_size_um2
# session_4_ventral2_20211130
# session_4_ventral2_20211130/chirp_preprocessed_traces
# session_4_ventral2_20211130/chirp_qi
# session_4_ventral2_20211130/chirp_raw_traces
# session_4_ventral2_20211130/chirp_smoothed_traces
# session_4_ventral2_20211130/chirp_spike_times
# session_4_ventral2_20211130/chirp_spikes
# session_4_ventral2_20211130/chirp_traces_times
# session_4_ventral2_20211130/chirp_trigger_times
# session_4_ventral2_20211130/d_qi
# session_4_ventral2_20211130/ds_index
# session_4_ventral2_20211130/group_assignment
# session_4_ventral2_20211130/group_confidences
# session_4_ventral2_20211130/mb_preprocessed_traces
# session_4_ventral2_20211130/mb_raw_traces
# session_4_ventral2_20211130/mb_smoothed_traces
# session_4_ventral2_20211130/mb_spike_times
# session_4_ventral2_20211130/mb_spikes
# session_4_ventral2_20211130/mb_traces_times
# session_4_ventral2_20211130/mb_trigger_times
# session_4_ventral2_20211130/natural_preprocessed_traces
# session_4_ventral2_20211130/natural_raw_traces
# session_4_ventral2_20211130/natural_smoothed_traces
# session_4_ventral2_20211130/natural_spike_times
# session_4_ventral2_20211130/natural_spikes
# session_4_ventral2_20211130/natural_traces_times
# session_4_ventral2_20211130/natural_trigger_times
# session_4_ventral2_20211130/os_index
# session_4_ventral2_20211130/pref_dir
# session_4_ventral2_20211130/roi_ids
# session_4_ventral2_20211130/roi_retinal_coords
# session_4_ventral2_20211130/roi_size_um2
# session_5_ventral1_20200226
# session_5_ventral1_20200226/chirp_preprocessed_traces
# session_5_ventral1_20200226/chirp_qi
# session_5_ventral1_20200226/chirp_raw_traces
# session_5_ventral1_20200226/chirp_smoothed_traces
# session_5_ventral1_20200226/chirp_spike_times
# session_5_ventral1_20200226/chirp_spikes
# session_5_ventral1_20200226/chirp_traces_times
# session_5_ventral1_20200226/chirp_trigger_times
# session_5_ventral1_20200226/d_qi
# session_5_ventral1_20200226/ds_index
# session_5_ventral1_20200226/group_assignment
# session_5_ventral1_20200226/group_confidences
# session_5_ventral1_20200226/mb_preprocessed_traces
# session_5_ventral1_20200226/mb_raw_traces
# session_5_ventral1_20200226/mb_smoothed_traces
# session_5_ventral1_20200226/mb_spike_times
# session_5_ventral1_20200226/mb_spikes
# session_5_ventral1_20200226/mb_traces_times
# session_5_ventral1_20200226/mb_trigger_times
# session_5_ventral1_20200226/natural_preprocessed_traces
# session_5_ventral1_20200226/natural_raw_traces
# session_5_ventral1_20200226/natural_smoothed_traces
# session_5_ventral1_20200226/natural_spike_times
# session_5_ventral1_20200226/natural_spikes
# session_5_ventral1_20200226/natural_traces_times
# session_5_ventral1_20200226/natural_trigger_times
# session_5_ventral1_20200226/os_index
# session_5_ventral1_20200226/pref_dir
# session_5_ventral1_20200226/roi_ids
# session_5_ventral1_20200226/roi_retinal_coords
# session_5_ventral1_20200226/roi_size_um2
# session_5_ventral2_20200303
# session_5_ventral2_20200303/chirp_preprocessed_traces
# session_5_ventral2_20200303/chirp_qi
# session_5_ventral2_20200303/chirp_raw_traces
# session_5_ventral2_20200303/chirp_smoothed_traces
# session_5_ventral2_20200303/chirp_spike_times
# session_5_ventral2_20200303/chirp_spikes
# session_5_ventral2_20200303/chirp_traces_times
# session_5_ventral2_20200303/chirp_trigger_times
# session_5_ventral2_20200303/d_qi
# session_5_ventral2_20200303/ds_index
# session_5_ventral2_20200303/group_assignment
# session_5_ventral2_20200303/group_confidences
# session_5_ventral2_20200303/mb_preprocessed_traces
# session_5_ventral2_20200303/mb_raw_traces
# session_5_ventral2_20200303/mb_smoothed_traces
# session_5_ventral2_20200303/mb_spike_times
# session_5_ventral2_20200303/mb_spikes
# session_5_ventral2_20200303/mb_traces_times
# session_5_ventral2_20200303/mb_trigger_times
# session_5_ventral2_20200303/natural_preprocessed_traces
# session_5_ventral2_20200303/natural_raw_traces
# session_5_ventral2_20200303/natural_smoothed_traces
# session_5_ventral2_20200303/natural_spike_times
# session_5_ventral2_20200303/natural_spikes
# session_5_ventral2_20200303/natural_traces_times
# session_5_ventral2_20200303/natural_trigger_times
# session_5_ventral2_20200303/os_index
# session_5_ventral2_20200303/pref_dir
# session_5_ventral2_20200303/roi_ids
# session_5_ventral2_20200303/roi_retinal_coords
# session_5_ventral2_20200303/roi_size_um2
# session_5_ventral2_20210910
# session_5_ventral2_20210910/chirp_preprocessed_traces
# session_5_ventral2_20210910/chirp_qi
# session_5_ventral2_20210910/chirp_raw_traces
# session_5_ventral2_20210910/chirp_smoothed_traces
# session_5_ventral2_20210910/chirp_spike_times
# session_5_ventral2_20210910/chirp_spikes
# session_5_ventral2_20210910/chirp_traces_times
# session_5_ventral2_20210910/chirp_trigger_times
# session_5_ventral2_20210910/d_qi
# session_5_ventral2_20210910/ds_index
# session_5_ventral2_20210910/group_assignment
# session_5_ventral2_20210910/group_confidences
# session_5_ventral2_20210910/mb_preprocessed_traces
# session_5_ventral2_20210910/mb_raw_traces
# session_5_ventral2_20210910/mb_smoothed_traces
# session_5_ventral2_20210910/mb_spike_times
# session_5_ventral2_20210910/mb_spikes
# session_5_ventral2_20210910/mb_traces_times
# session_5_ventral2_20210910/mb_trigger_times
# session_5_ventral2_20210910/natural_preprocessed_traces
# session_5_ventral2_20210910/natural_raw_traces
# session_5_ventral2_20210910/natural_smoothed_traces
# session_5_ventral2_20210910/natural_spike_times
# session_5_ventral2_20210929/roi_size_um2
# session_6_ventral2_20210921
# session_6_ventral2_20210921/chirp_preprocessed_traces
# session_6_ventral2_20210921/chirp_qi
# session_6_ventral2_20210921/chirp_raw_traces
# session_6_ventral2_20210921/chirp_smoothed_traces
# session_6_ventral2_20210921/chirp_spike_times
# session_6_ventral2_20210921/chirp_spikes
# session_6_ventral2_20210921/chirp_traces_times
# session_6_ventral2_20210921/chirp_trigger_times
# session_6_ventral2_20210921/d_qi
# session_6_ventral2_20210921/ds_index
# session_6_ventral2_20210921/group_assignment
# session_6_ventral2_20210921/group_confidences
# session_6_ventral2_20210921/mb_preprocessed_traces
# session_6_ventral2_20210921/mb_raw_traces
# session_6_ventral2_20210921/mb_smoothed_traces
# session_6_ventral2_20210921/mb_spike_times
# session_6_ventral2_20210921/mb_spikes
# session_6_ventral2_20210921/mb_traces_times
# session_6_ventral2_20210921/mb_trigger_times
# session_6_ventral2_20210921/natural_preprocessed_traces
# session_6_ventral2_20210921/natural_raw_traces
# session_6_ventral2_20210921/natural_smoothed_traces
# session_6_ventral2_20210921/natural_spike_times
# session_6_ventral2_20210921/natural_spikes
# session_6_ventral2_20210921/natural_traces_times
# session_6_ventral2_20210921/natural_trigger_times
# session_6_ventral2_20210921/os_index
# session_6_ventral2_20210921/pref_dir
# session_6_ventral2_20210921/roi_ids
# session_6_ventral2_20210921/roi_retinal_coords
# session_6_ventral2_20210921/roi_size_um2
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 14
#      12     print(name, obj.shape)
#      13 f.visit(printname)
# ---> 14 f.visititems(printshape)
#      15 # wDataCh0 = f['wDataCh0'][:]
#      16 # wParamsStr = f['wParamsStr'][:]
#
# File /.pyenv/versions/miniconda3-latest/lib/python3.12/site-packages/h5py/_hl/group.py:674, in Group.visititems(self, func)
#     672     name = self._d(name)
#     673     return func(name, self[name])
# --> 674 return h5o.visit(self.id, proxy)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5o.pyx:422, in h5py.h5o.visit()
#
# File h5py/h5o.pyx:369, in h5py.h5o.cb_obj_simple()
#
# File /.pyenv/versions/miniconda3-latest/lib/python3.12/site-packages/h5py/_hl/group.py:673, in Group.visititems.<locals>.proxy(name)
#     671 """ Use the text name of the object, not bytes """
#     672 name = self._d(name)
# --> 673 return func(name, self[name])
#
# Cell In[48], line 12, in printshape(name, obj)
#      11 def printshape(name, obj):
# ---> 12     print(name, obj.shape)
#
# AttributeError: 'Group' object has no attribute 'shape'

# %%
wParamsStr
# Out:
# array([b'01D68200E29C670084BE2329AED66CE1', b'euler14_01', b'eulerlab',
#        b'C:\\Users\\eulerlab\\Documents\\WaveMetrics\\IgorPro6UserFiles\\ScanM_Data\\M1_LR_GCL0_MC_new.smp',
#        b'2020-9-3', b'14-45-36-752', b'0.0.36.61_4',
#        b'C:\\ProgramFiles(x86)\\WaveMetrics\\IgorProFolder\\Igor.exe',
#        b'6.3.7.2', b'5120;5120;5120;',
#        b'128000.000000;128000.000000;128000.000000;', b'2560;2560;2560;',
#        b'XYScan2|5120|80|64|10|6|0|1', b'0.0.38.02', b'n/a', b'n/a',
#        b'128000.000000;128000.000000;128000.000000;'], dtype=object)

# %% [markdown]
# ## setup the schema

# %%
import os
import os
import datajoint as dj
from djimaging.user.ssuhai.schemas.ssuhai_schema import *
from djimaging.utils.dj_utils import activate_schema
import warnings
warnings.simplefilter("ignore", FutureWarning)

# %%
username = !whoami
username = username[0]
home_directory = os.path.expanduser("~")
path_to_djimaging = f'{home_directory}/GitRepos'
config_file = f'{home_directory}/datajoint/dj_{username}_conf.json'
assert os.path.isfile(config_file), f'Set the path to your config file: {config_file}'
schema_name = f"ageuler_{username}_test"

# %%
# Load configuration for user
dj.config.load(config_file)
dj.config['schema_name'] = schema_name

print("schema_name:", dj.config['schema_name'])
dj.conn()
# Out:
# [2025-04-22 16:54:40,403][INFO]: Connecting ssuhai@172.25.240.200:3306
# [2025-04-22 16:54:40,459][INFO]: Connected ssuhai@172.25.240.200:3306
# schema_name: ageuler_ssuhai_test
# DataJoint connection (connected) ssuhai@172.25.240.200:3306

# %%
activate_schema(schema=schema, create_schema=True, create_tables=True)

# %%
dj.ERD(schema)

# %% [markdown]
# ## First iter

# %%
# 1. Set initial user info

userinfo = {
    'experimenter': 'closedlooptest', # Replace this if you want to use your own data
    'data_dir': '/gpfs01/euler/User/ssuhai/GitRepos/simulation_closed_loop/data/recordings/updated_loop_data', # Replace this if you want to use your own data
    'animal_loc': 1,
    'region_loc': 2,
    'field_loc': 3,
    'stimulus_loc': 4,
    'cond1_loc': 5,
}

# %% [markdown]
# ### Populate some tables

# %%
UserInfo().upload_user(userinfo)
if len(RawDataParams()) == 0:
    RawDataParams().add_default()
RawDataParams().update1(dict(experimenter='closedlooptest',raw_id=int(1),
                             from_raw_data=int(1),
                             igor_roi_masks='no',
                             ))

# %%
# 2. set parameters for Raw data
# raw_params_dict = {
#     'experimenter': 'closedlooptest',
#     'raw_id': 1,
#     'from_raw_data': 1, 
#     'compute_from_stack': 1,
#     'include_artifacts': 0,
#     'trace_precision': 'line',
#     'trigger_precision': 'line',
#     'igor_roi_masks': 'no'
#     }




Experiment().rescan_filesystem(verboselvl=3)
Field().rescan_filesystem(verboselvl=3)
# Out:
# Scanning for experimenter: closedlooptest
# 	header_path: /gpfs01/euler/User/ssuhai/GitRepos/simulation_closed_loop/data/recordings/updated_loop_data/20250412/1
# 		header_name: 20220217__left.ini
# 		Adding: {'experimenter': 'closedlooptest', 'date': datetime.datetime(2025, 4, 12, 0, 0), 'exp_num': 1}
# Found 1 files in 1 fields for key={'experimenter': 'closedlooptest', 'date': datetime.date(2025, 4, 12), 'exp_num': 1, 'raw_id': 1}
# 	Adding field: `{'field': 'GCL0', 'region': 'RR', 'cond1': 'iter0', 'experimenter': 'closedlooptest', 'date': datetime.date(2025, 4, 12), 'exp_num': 1, 'raw_id': 1}`

# %%
Field()
# Out:
# *experimenter  *date          *exp_num    *raw_id    *field    *region    *cond1    field_data_fil absx        absy       absz        scan_type     npixartifact   nxpix     nypix     nzpix     nxpix_offset   nxpix_retrace  pixel_size_um  z_step_um
# +------------+ +------------+ +---------+ +--------+ +-------+ +--------+ +-------+ +------------+ +---------+ +--------+ +---------+ +-----------+ +------------+ +-------+ +-------+ +-------+ +------------+ +------------+ +------------+ +-----------+
# closedlooptest 2025-04-12     1           1          GCL0      RR         iter0     /gpfs01/euler/ -2310.7     1545.0     -2290.3     xy            1              64        64        0         6              10             2.01149        nan
#  (Total: 1)

# %%
import h5py

with h5py.File("/gpfs01/euler/User/ssuhai/GitRepos/simulation_closed_loop/data/stimuli/original/noise.h5", "r") as f:
    noise_stimulus = f['stimulusarray'][:].T.astype(int)

# %%
# # TODO add dynamic
# Stimulus().add_chirp(spatialextent=1000, stim_name='gChirp', alias="chirp_gchirp_globalchirp", skip_duplicates=True)
iteration = 0
stim_name = f'closedloop{iteration}'
alias=f"closedloop{iteration}_cl{iteration}_{iteration}closedloop"
# lets try my custom stimlulus
Stimulus().add_noise(stim_name=stim_name, alias=alias, pix_n_x=20, pix_n_y=15, pix_scale_x_um=30, pix_scale_y_um=30, stim_trace=noise_stimulus, skip_duplicates=True)


Stimulus()
# Out:
# /gpfs01/euler/User/ssuhai/GitRepos/djimaging/djimaging/tables/core/stimulus.py:195: UserWarning: Stimulus offset not set. Assuming 0 offset. This is incorrect for the standard dense noise stimulus.
#   warnings.warn(
# /gpfs01/euler/User/ssuhai/GitRepos/djimaging/djimaging/tables/core/stimulus.py:203: UserWarning: Stimulus offset not set. Assuming 0 offset. This is incorrect for the standard dense noise stimulus.
#   warnings.warn(
# *stim_name     alias          stim_family    framerate     isrepeated     ntrigger_rep   stim_path     commit_id     stim_hash     trial_info stim_trace stim_dict  snippet_base_d
# +------------+ +------------+ +------------+ +-----------+ +------------+ +------------+ +-----------+ +-----------+ +-----------+ +--------+ +--------+ +--------+ +------------+
# closedloop0    closedloop0_cl noise          5.0           0              1500                                                     =BLOB=     =BLOB=     =BLOB=     nan
#  (Total: 1)

# %%
Presentation().populate(processes=20, display_progress=True)
# Out:
# Presentation:   0%|          | 0/1 [00:00<?, ?it/s]
# Presentation: 100%|██████████| 1/1 [00:03<00:00,  3.44s/it]
# {'success_count': 1, 'error_list': []}

# %%
Presentation()
# Out:
# *experimenter  *date          *exp_num    *raw_id    *field    *region    *cond1    *stim_name     *cond2      pres_data_file triggertim trigger_valid  absx        absy       absz        scan_type     npixartifact   nxpix     nypix     nzpix     nxpix_offset   nxpix_retrace  pixel_size_um  z_step_um     nframes
# +------------+ +------------+ +---------+ +--------+ +-------+ +--------+ +-------+ +------------+ +---------+ +------------+ +--------+ +------------+ +---------+ +--------+ +---------+ +-----------+ +------------+ +-------+ +-------+ +-------+ +------------+ +------------+ +------------+ +-----------+ +---------+
# closedlooptest 2025-04-12     1           1          GCL0      RR         iter0     closedloop0    control     /gpfs01/euler/ =BLOB=     1              -2310.7     1545.0     -2290.3     xy            1              64        64        0         6              10             2.01149        nan           2569
#  (Total: 1)

# %%
Presentation().plot1()

# %% [markdown]
# ### autorois

# %%
# load ROI masks if they exist
RoiMask().rescan_filesystem(verboselvl=3)
missing_fields = RoiMask().list_missing_field()
field_key = missing_fields[0]

# TODO
# somehow there is an error in getting some property of the loaded smp file object 
# but the error occurs in the SMH class. Some dict key is not found.
roi_canvas = RoiMask().draw_roi_mask(field_key=field_key, canvas_width=30)
# Out:
# field_key: {'experimenter': 'closedlooptest', 'date': datetime.date(2025, 4, 12), 'exp_num': 1, 'raw_id': 1, 'field': 'GCL0', 'region': 'RR', 'cond1': 'iter0'}
# pres_keys: [{'experimenter': 'closedlooptest', 'date': datetime.date(2025, 4, 12), 'exp_num': 1, 'raw_id': 1, 'field': 'GCL0', 'region': 'RR', 'cond1': 'iter0', 'stim_name': 'closedloop0', 'cond2': 'control'}]
# No ROI masks found for field: {'experimenter': 'closedlooptest', 'date': datetime.date(2025, 4, 12), 'exp_num': 1, 'raw_id': 1, 'field': 'GCL0', 'region': 'RR', 'cond1': 'iter0'}
# pres_keys: [{'experimenter': 'closedlooptest', 'date': datetime.date(2025, 4, 12), 'exp_num': 1, 'raw_id': 1, 'field': 'GCL0', 'region': 'RR', 'cond1': 'iter0', 'stim_name': 'closedloop0', 'cond2': 'control'}]
# Load model weights for cpu from checkpoint /gpfs01/euler/data/Resources/AutoROIs/models/UNET_v0.1.0/dropout_and_aug_regul.ckpt using config /gpfs01/euler/data/Resources/AutoROIs/models/UNET_v0.1.0/sd_images.yaml
# Returned InteractiveRoiCanvas object. To start GUI, call <enter_object_name>.start_gui().

# %%
from IPython.display import display
gui = roi_canvas.start_gui()
display(gui)
roi_canvas.exec_autorois_all()
roi_canvas.exec_save_to_file()
# Out:
# VBox(children=(HBox(children=(VBox(children=(MultiCanvas(height=256, layout=Layout(height='auto', width='100%'…

# %%
roi_canvas.insert_database(roi_mask_tab=RoiMask, field_key=field_key)

# %%
Roi().populate(processes=20, display_progress=True)
Traces().populate(processes=20, display_progress=True)
Traces().plot()
# Out:
# Roi:   0%|          | 0/1 [00:00<?, ?it/s]
# Roi: 100%|██████████| 1/1 [00:00<00:00,  4.04it/s]
# Traces: 100%|██████████| 1/1 [00:03<00:00,  3.40s/it]

# %% [markdown]
# ## New loop iteration

# %% [markdown]
# lets try to add another presentation to the presentations table. This seems like the most natural integration into the pipeline

# %%
Stimulus()
# Out:
# *stim_name     alias          stim_family    framerate     isrepeated     ntrigger_rep   stim_path     commit_id     stim_hash     trial_info stim_trace stim_dict  snippet_base_d
# +------------+ +------------+ +------------+ +-----------+ +------------+ +------------+ +-----------+ +-----------+ +-----------+ +--------+ +--------+ +--------+ +------------+
# closedloop1    closedloop1_cl                0.0           1              2                                                        =BLOB=     =BLOB=     =BLOB=     nan
# closedloop2    closedloop2_cl                0.0           1              2                                                        =BLOB=     =BLOB=     =BLOB=     nan
#  (Total: 2)

# %% [markdown]
# first move more files to simulate additional presentation
# the only thing that changes is the stimulus name. I did this in the terminal
#
# Rescaning fields does not do anything because it we already have a field
#
# It seems like we cannot add the same chirp again.
# If we give it random aliases then the process loading the stimulus file
# gives an error because the stimlulus file does not have my random alias.
# Lets try to add a noise stimulus:
# it also does not work with the noise stimlulus to add the same stimulus again
# There seem to be two options: 1) create an own stmulus or
# 2) go with one different experiment per closed loop iteration
# Since sooner or later I probably have to do own stimuli anyway, I will go try option 1)
# It seems to be simple to add an own stimlulus lets see if we can simply add a second one.
# That seemed to work. we see a second row in the presentations table.
#
# Next lets copy the roi masks and try to populate traces again. Okay that did not work. We still have to insert the ROIs in RoiMask. Lets just call the gui again and after copying the roi mask and use the .insertdatabase method. Hopwfully this will also take care of dependencies between tables such as with the Field table, which is linked to the RoiMasks table.
#
# WOOOOW! conditions can be added at the index 4 of the file name. this changes everything. I can maybe see the condition as loop iteration.

# %%
noise_dict = (Stimulus() & 'stim_name="noise"').fetch1()
noise_dict.keys()
# Out:
# dict_keys(['stim_name', 'alias', 'stim_family', 'framerate', 'isrepeated', 'ntrigger_rep', 'stim_path', 'commit_id', 'stim_hash', 'trial_info', 'stim_trace', 'stim_dict', 'snippet_base_dt'])

# %%
Field().rescan_filesystem(verboselvl=3)
# Out:
# Found 2 files in 2 fields for key={'experimenter': 'closedlooptest', 'date': datetime.date(2025, 4, 12), 'exp_num': 1, 'raw_id': 1}
# 	Skipping field `{'field': 'GCL0', 'region': 'LR', 'cond1': 'iter1', 'experimenter': 'closedlooptest', 'date': datetime.date(2025, 4, 12), 'exp_num': 1, 'raw_id': 1}` because it already exists
# 	Adding field: `{'field': 'GCL0', 'region': 'LR', 'cond1': 'iter2', 'experimenter': 'closedlooptest', 'date': datetime.date(2025, 4, 12), 'exp_num': 1, 'raw_id': 1}`

# %%
# Add custom stimulus if needed
Stimulus().add_stimulus(stim_name='closedloop2', alias="closedloop2_cl2_secondclosedloop", isrepeated=True, ntrigger_rep=2,
                        trial_info=[1, 2], skip_duplicates=True)

# %%
# next populate presentations.
Presentation().populate()
# Out:
# {'success_count': 3, 'error_list': []}

# %%
# this seemed to work
Presentation()
# Out:
# *experimenter  *date          *exp_num    *raw_id    *field    *region    *cond1    *stim_name     *cond2      pres_data_file triggertim trigger_valid  absx       absy        absz       scan_type     npixartifact   nxpix     nypix     nzpix     nxpix_offset   nxpix_retrace  pixel_size_um  z_step_um     nframes
# +------------+ +------------+ +---------+ +--------+ +-------+ +--------+ +-------+ +------------+ +---------+ +------------+ +--------+ +------------+ +--------+ +---------+ +--------+ +-----------+ +------------+ +-------+ +-------+ +-------+ +------------+ +------------+ +------------+ +-----------+ +---------+
# closedlooptest 2025-04-12     1           1          GCL0      LR         iter1     closedloop1    control     /gpfs01/euler/ =BLOB=     1              979.24     -2575.6     1645.9     xy            3              64        64        1         6              10             1.46998        nan           1429
# closedlooptest 2025-04-12     1           1          GCL0      LR         iter2     closedloop1    control     /gpfs01/euler/ =BLOB=     1              979.24     -2575.6     1645.9     xy            3              64        64        1         6              10             1.46998        nan           1429
#  (Total: 2)

# %%
# load ROI masks if they exist
RoiMask().rescan_filesystem(verboselvl=3)
missing_fields = RoiMask().list_missing_field()
field_key = missing_fields[0]
# Out:
# field_key: {'experimenter': 'closedlooptest', 'date': datetime.date(2025, 4, 12), 'exp_num': 1, 'raw_id': 1, 'field': 'GCL0', 'region': 'LR', 'cond1': 'iter2'}
# pres_keys: [{'experimenter': 'closedlooptest', 'date': datetime.date(2025, 4, 12), 'exp_num': 1, 'raw_id': 1, 'field': 'GCL0', 'region': 'LR', 'cond1': 'iter2', 'stim_name': 'closedloop1', 'cond2': 'control'}]
# No ROI masks found for field: {'experimenter': 'closedlooptest', 'date': datetime.date(2025, 4, 12), 'exp_num': 1, 'raw_id': 1, 'field': 'GCL0', 'region': 'LR', 'cond1': 'iter2'}
# pres_keys: [{'experimenter': 'closedlooptest', 'date': datetime.date(2025, 4, 12), 'exp_num': 1, 'raw_id': 1, 'field': 'GCL0', 'region': 'LR', 'cond1': 'iter2', 'stim_name': 'closedloop1', 'cond2': 'control'}]

# %%
# next we need to reuse the Roi mask somehow
# lets try to do this by just copying the roi mask pkl file and renaming it to match the new stimlus name.
# i did this in the shell. Next we can inserting another row in the RoiMask table


# TODO
# somehow there is an error in getting some property of the loaded smp file object 
# but the error occurs in the SMH class. Some dict key is not found.
roi_canvas = RoiMask().draw_roi_mask(field_key=field_key, canvas_width=30)
roi_canvas.start_gui()
# Out:
# Load model weights for cpu from checkpoint /gpfs01/euler/data/Resources/AutoROIs/models/UNET_v0.1.0/dropout_and_aug_regul.ckpt using config /gpfs01/euler/data/Resources/AutoROIs/models/UNET_v0.1.0/sd_images.yaml
# Returned InteractiveRoiCanvas object. To start GUI, call <enter_object_name>.start_gui().
# VBox(children=(HBox(children=(VBox(children=(MultiCanvas(height=256, layout=Layout(height='auto', width='100%'…

# %%
roi_canvas.insert_database(roi_mask_tab=RoiMask, field_key=field_key)
Roi().populate(processes=20, display_progress=True)
Traces().populate(processes=20, display_progress=True)
# Out:
# Roi: 100%|██████████| 1/1 [00:00<00:00,  3.74it/s]
# Traces: 100%|██████████| 1/1 [00:02<00:00,  2.05s/it]
# {'success_count': 1, 'error_list': []}

# %%
def clear_tabels():
    UserInfo().delete()
    Experiment().delete()
    Field().delete()
    Stimulus().delete()
    RoiMask().delete()
    Roi().delete()
    Traces().delete()
    Presentation().delete()
    RawDataParams().delete()

clear_tabels()
# Out:
# [2025-04-22 19:41:07,471][WARNING]: MySQL server has gone away. Reconnecting to the server.
# [2025-04-22 19:41:07,609][INFO]: Deleting 3 rows from `ageuler_ssuhai_test`.`__field__stack_averages`
# [2025-04-22 19:41:07,681][INFO]: Deleting 1 rows from `ageuler_ssuhai_test`.`__presentation__scan_info`
# [2025-04-22 19:41:07,729][INFO]: Deleting 3 rows from `ageuler_ssuhai_test`.`__presentation__stack_averages`
# [2025-04-22 19:41:07,785][INFO]: Deleting 97 rows from `ageuler_ssuhai_test`.`__traces`
# [2025-04-22 19:41:07,832][INFO]: Deleting 1 rows from `ageuler_ssuhai_test`.`roi_mask__roi_mask_presentation`
# [2025-04-22 19:41:07,909][INFO]: Deleting 97 rows from `ageuler_ssuhai_test`.`__roi`
# [2025-04-22 19:41:07,934][INFO]: Deleting 1 rows from `ageuler_ssuhai_test`.`roi_mask`
# [2025-04-22 19:41:07,959][INFO]: Deleting 1 rows from `ageuler_ssuhai_test`.`__presentation`
# [2025-04-22 19:41:07,983][INFO]: Deleting 1 rows from `ageuler_ssuhai_test`.`__field`
# [2025-04-22 19:41:08,011][INFO]: Deleting 1 rows from `ageuler_ssuhai_test`.`#raw_data_params`
# [2025-04-22 19:41:08,071][INFO]: Deleting 1 rows from `ageuler_ssuhai_test`.`__experiment__animal`
# [2025-04-22 19:41:08,116][INFO]: Deleting 1 rows from `ageuler_ssuhai_test`.`__experiment__exp_info`
# [2025-04-22 19:41:08,161][INFO]: Deleting 1 rows from `ageuler_ssuhai_test`.`__experiment__indicator`
# [2025-04-22 19:41:08,206][INFO]: Deleting 1 rows from `ageuler_ssuhai_test`.`__experiment__pharm_info`
# [2025-04-22 19:41:08,230][INFO]: Deleting 1 rows from `ageuler_ssuhai_test`.`__experiment`
# [2025-04-22 19:41:08,255][INFO]: Deleting 1 rows from `ageuler_ssuhai_test`.`user_info`
# [2025-04-22 19:41:10,830][INFO]: Deletes committed.
# [2025-04-22 19:41:10,858][INFO]: Deleting 0 rows from `ageuler_ssuhai_test`.`__experiment`
# [2025-04-22 19:41:10,859][WARNING]: Nothing to delete.
# [2025-04-22 19:41:10,887][INFO]: Deleting 0 rows from `ageuler_ssuhai_test`.`__field`
# [2025-04-22 19:41:10,889][WARNING]: Nothing to delete.
# [2025-04-22 19:41:10,917][INFO]: Deleting 1 rows from `ageuler_ssuhai_test`.`stimulus`
# [2025-04-22 19:41:12,742][INFO]: Deletes committed.
# [2025-04-22 19:41:12,770][INFO]: Deleting 0 rows from `ageuler_ssuhai_test`.`roi_mask`
# [2025-04-22 19:41:12,771][WARNING]: Nothing to delete.
# [2025-04-22 19:41:12,799][INFO]: Deleting 0 rows from `ageuler_ssuhai_test`.`__roi`
# [2025-04-22 19:41:12,801][WARNING]: Nothing to delete.
# [2025-04-22 19:41:12,829][INFO]: Deleting 0 rows from `ageuler_ssuhai_test`.`__traces`
# [2025-04-22 19:41:12,830][WARNING]: Nothing to delete.
# [2025-04-22 19:41:12,858][INFO]: Deleting 0 rows from `ageuler_ssuhai_test`.`__presentation`
# [2025-04-22 19:41:12,859][WARNING]: Nothing to delete.
# [2025-04-22 19:41:12,887][INFO]: Deleting 0 rows from `ageuler_ssuhai_test`.`#raw_data_params`
# [2025-04-22 19:41:12,888][WARNING]: Nothing to delete.

# %%
if input("Continue with cleaning up? (yes/no))") != "yes":
    raise ValueError('Enter yes if you wish to continue.')

schema.drop()
