# %% [markdown]
# ## imports and setup

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import hydra
from omegaconf import DictConfig, OmegaConf
import os
from time import sleep

# %% [markdown]
# ## configs

# %%
cwd = os.getcwd()
path_to_repo = "GitRepos/simulation_closed_loop"
full_repo_path = os.path.join(cwd,path_to_repo)

config_path = os.path.join(path_to_repo, "config")
assert os.path.exists(config_path), f"Config path {config_path} does not exist."

# Initialize Hydra
try:
    hydra.initialize(config_path=config_path)
except Exception as e:
    print(f"Likely alredy initialized hydra, need ot restart kernel to reinitialize. Error: {e}")

# Compose the configuration
cfg = hydra.compose(config_name="config")

import sys
sys.path.append(os.path.join(full_repo_path))
# Out:
# /tmp/ipykernel_896843/1073692694.py:10: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   hydra.initialize(config_path=config_path)

# %% [markdown]
# ## get simulation loop components

# %%
# TODO: debugging
# change of congifs for recorder, modify recorder to change only condition (commit after this) ,test if preprocessor works

from simulations.run_simulation import create_loop_components
recorder, preprocessor, model, stimulator = create_loop_components(cfg)

# %% [markdown]
# ## Run the simulation

# %%
iterations = 2

for iter in range(iterations):
    print(f"Iteration {iter+1}/{iterations}")
   
    # Run the simulation
    recorder.record()
    
    # Process the data
    preprocessor.process_data(connect_and_activate=True)
    
    # sleep 
    sleep(1)
# Out:
# Iteration 1/2
# schema_name: ageuler_ssuhai_test
# Scanning for experimenter: closedlooptest
# 	header_path: /gpfs01/euler/User/ssuhai/GitRepos/simulation_closed_loop/data/recordings/updated_loop_data/20250412/1
# 		header_name: 20190701__left.ini
# 		Adding: {'experimenter': 'closedlooptest', 'date': datetime.datetime(2025, 4, 12, 0, 0), 'exp_num': 1}
# Found 3 files in 3 fields for key={'experimenter': 'closedlooptest', 'date': datetime.date(2025, 4, 12), 'exp_num': 1, 'raw_id': 1}
# 	Adding field: `{'field': 'GCL0', 'region': 'LR', 'cond1': 'iter0', 'experimenter': 'closedlooptest', 'date': datetime.date(2025, 4, 12), 'exp_num': 1, 'raw_id': 1}`
# 	Adding field: `{'field': 'GCL0', 'region': 'LR', 'cond1': 'iter1', 'experimenter': 'closedlooptest', 'date': datetime.date(2025, 4, 12), 'exp_num': 1, 'raw_id': 1}`
# 	Adding field: `{'field': 'GCL0', 'region': 'LR', 'cond1': 'iter2', 'experimenter': 'closedlooptest', 'date': datetime.date(2025, 4, 12), 'exp_num': 1, 'raw_id': 1}`
# Processes:   0%|          | 0/3 [00:00<?, ?it/s]ERROR:tornado.general:SEND Error: Host unreachable
# Processes:   0%|          | 0/3 [04:57<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File /.pyenv/versions/miniconda3-latest/lib/python3.12/multiprocessing/pool.py:856, in IMapIterator.next(self, timeout)
#     855 try:
# --> 856     item = self._items.popleft()
#     857 except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 10
#       7 recorder.record()
#       9 # Process the data
# ---> 10 preprocessor.process_data(connect_and_activate=True)
#      12 # sleep
#      13 sleep(1)
#
# File ~/GitRepos/simulation_closed_loop/simulations/loop_components/preprocessors/preprocessor1.py:241, in Preprocessor1.process_data(self, connect_and_activate)
#     238         sleep(self.sleep_time_between_table_ops)
#     239     self.set_metadata()
# --> 241 self.upload_iteration_data()
#     242 self.add_iteration_rois()
#     243 self.add_iteration_traces()
#
# File ~/GitRepos/simulation_closed_loop/simulations/loop_components/preprocessors/preprocessor1.py:146, in Preprocessor1.upload_iteration_data(self)
#     142 Stimulus().add_stimulus(stim_name=f'closedloop{self.iteration}', alias=f"closedloop{self.iteration}_cl{self.iteration}_{self.iteration}closedloop", isrepeated=True, ntrigger_rep=2,
#     143                         trial_info=[1, 2], skip_duplicates=True)
#     144 sleep(self.sleep_time_between_table_ops)
# --> 146 Presentation().populate(processes=20, display_progress=True)
#     147 sleep(self.sleep_time_between_table_ops)
#
# File /.pyenv/versions/miniconda3-latest/lib/python3.12/site-packages/datajoint/autopopulate.py:272, in AutoPopulate.populate(self, keys, suppress_errors, return_exception_objects, reserve_jobs, order, limit, max_calls, display_progress, processes, make_kwargs, *restrictions)
#     264 del self.connection._conn.ctx  # SSLContext is not pickleable
#     265 with mp.Pool(
#     266     processes, _initialize_populate, (self, jobs, populate_kwargs)
#     267 ) as pool, (
#    (...)
#     270     else contextlib.nullcontext()
#     271 ) as progress_bar:
# --> 272     for status in pool.imap(_call_populate1, keys, chunksize=1):
#     273         if status is True:
#     274             success_list.append(1)
#
# File /.pyenv/versions/miniconda3-latest/lib/python3.12/multiprocessing/pool.py:861, in IMapIterator.next(self, timeout)
#     859     self._pool = None
#     860     raise StopIteration from None
# --> 861 self._cond.wait(timeout)
#     862 try:
#     863     item = self._items.popleft()
#
# File /.pyenv/versions/miniconda3-latest/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %%
recorder.clean_up()
preprocessor.clean_up()
# Out:
# ---------------------------------------------------------------------------
# DataJointError                            Traceback (most recent call last)
# Cell In[36], line 2
#       1 #recorder.clean_up()
# ----> 2 preprocessor.clean_up()
#
# File ~/GitRepos/simulation_closed_loop/simulations/loop_components/preprocessors/preprocessor1.py:153, in Preprocessor1.clean_up(self)
#     149 def clean_up(self) -> None:
#     150     """
#     151     clean up tables instance back to initial state
#     152     """
# --> 153     self.clear_schema_tabels()
#     155     self.iteration = 0
#
# File ~/GitRepos/simulation_closed_loop/simulations/loop_components/preprocessors/preprocessor1.py:159, in Preprocessor1.clear_schema_tabels(self)
#     157 def clear_schema_tabels(self) -> None:
# --> 159     UserInfo().delete()
#     160     sleep(self.sleep_time_between_table_ops)
#     162     Experiment().delete()
#
# File /.pyenv/versions/miniconda3-latest/lib/python3.12/site-packages/datajoint/table.py:616, in Table.delete(self, transaction, safemode, force_parts, force_masters)
#     614             transaction = False
#     615         else:
# --> 616             raise DataJointError(
#     617                 "Delete cannot use a transaction within an ongoing transaction. "
#     618                 "Set transaction=False or safemode=False)."
#     619             )
#     621 # Cascading delete
#     622 try:
#
# DataJointError: Delete cannot use a transaction within an ongoing transaction. Set transaction=False or safemode=False).
