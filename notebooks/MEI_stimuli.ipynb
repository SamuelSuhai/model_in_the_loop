# %%
from time import perf_counter
from functools import wraps

# %%
@time_it
def some_function():
    # Simulating some work
    total = 0
    for i in range(1000000):
        total += i

# %%
some_function()
# Out:
# Function some_function took 0.064442 seconds to execute.
